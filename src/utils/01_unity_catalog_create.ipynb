# %%
# %sql
CREATE CATALOG IF NOT EXISTS shopmetrics_ecommerce;
CREATE SCHEMA IF NOT EXISTS shopmetrics_ecommerce.bronze;
CREATE SCHEMA IF NOT EXISTS shopmetrics_ecommerce.silver;
CREATE SCHEMA IF NOT EXISTS shopmetrics_ecommerce.gold;
